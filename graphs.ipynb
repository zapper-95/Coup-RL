# %%
import pandas as pd
import matplotlib.pyplot as plt

# use pandas to import hte data from the csv file
data = pd.read_csv('PPO_Coup_1bd85_00010_10_clip_param-0.2000-gamma-0.9000-train_batch_size-20000_2024-04-22_01-21-03.csv')

# %%
# turn into a graph
data.plot(x='Step', y="Value")
# Out:
# <Axes: xlabel='Step'>
