# %%
# import all .csv files in the current directory and merge them into one .csv file
import os
import pandas as pd
import matplotlib.pyplot as plt

csv_files = [f for f in os.listdir('.') if f.endswith('.csv')]



# make seperate df for each csv file
dfs = [pd.read_csv(f) for f in csv_files]

# %%
for df in dfs:
    df.rename(columns={"Value": "Win Rate"}, inplace=True)

# %%
len(dfs)
# Out:
# 18

# %%
csv_files


hyperparams = [file[len("test_1_PPO_Coup_1bd85_00000_0_"):].split("_2024")[0] for file in csv_files]

hyperparams
# Out:
# ['clip_param-0.1000-gamma-0.9000-train_batch_size-10000',
#  'clip_param-0.2000-gamma-0.9000-train_batch_size-10000',
#  'clip_param-0.3000-gamma-0.9000-train_batch_size-10000',
#  'clip_param-0.1000-gamma-0.9500-train_batch_size-10000',
#  'clip_param-0.2000-gamma-0.9500-train_batch_size-10000',
#  'clip_param-0.3000-gamma-0.9500-train_batch_size-10000',
#  'clip_param-0.1000-gamma-0.9900-train_batch_size-10000',
#  'clip_param-0.2000-gamma-0.9900-train_batch_size-10000',
#  'clip_param-0.3000-gamma-0.9900-train_batch_size-10000',
#  'clip_param-0.1000-entropy_coeff-0.0100-gamma-0.9500',
#  'clip_param-0.2000-entropy_coeff-0.0100-gamma-0.9500',
#  'clip_param-0.3000-entropy_coeff-0.0100-gamma-0.9500',
#  'clip_param-0.1000-entropy_coeff-0.0010-gamma-0.9500',
#  'clip_param-0.2000-entropy_coeff-0.0010-gamma-0.9500',
#  'clip_param-0.3000-entropy_coeff-0.0010-gamma-0.9500',
#  'clip_param-0.1000-entropy_coeff-0.0001-gamma-0.9500',
#  'clip_param-0.2000-entropy_coeff-0.0001-gamma-0.9500',
#  'clip_param-0.3000-entropy_coeff-0.0001-gamma-0.9500']

# %%
csv_files
# Out:
# ['test_1_PPO_Coup_1bd85_00000_0_clip_param-0.1000-gamma-0.9000-train_batch_size-10000_2024-04-21_20-26-53.csv',
#  'test_1_PPO_Coup_1bd85_00001_1_clip_param-0.2000-gamma-0.9000-train_batch_size-10000_2024-04-21_20-50-44.csv',
#  'test_1_PPO_Coup_1bd85_00002_2_clip_param-0.3000-gamma-0.9000-train_batch_size-10000_2024-04-21_21-28-22.csv',
#  'test_1_PPO_Coup_1bd85_00003_3_clip_param-0.1000-gamma-0.9500-train_batch_size-10000_2024-04-21_21-54-16.csv',
#  'test_1_PPO_Coup_1bd85_00004_4_clip_param-0.2000-gamma-0.9500-train_batch_size-10000_2024-04-21_22-20-05.csv',
#  'test_1_PPO_Coup_1bd85_00005_5_clip_param-0.3000-gamma-0.9500-train_batch_size-10000_2024-04-21_22-44-47.csv',
#  'test_1_PPO_Coup_1bd85_00006_6_clip_param-0.1000-gamma-0.9900-train_batch_size-10000_2024-04-21_23-10-35.csv',
#  'test_1_PPO_Coup_1bd85_00007_7_clip_param-0.2000-gamma-0.9900-train_batch_size-10000_2024-04-21_23-37-22.csv',
#  'test_1_PPO_Coup_1bd85_00008_8_clip_param-0.3000-gamma-0.9900-train_batch_size-10000_2024-04-22_00-04-34.csv',
#  'test_2_PPO_Coup_8d620_00000_0_clip_param-0.1000-entropy_coeff-0.0100-gamma-0.9500_2024-04-22_20-57-30.csv',
#  'test_2_PPO_Coup_8d620_00001_1_clip_param-0.2000-entropy_coeff-0.0100-gamma-0.9500_2024-04-22_21-45-33.csv',
#  'test_2_PPO_Coup_8d620_00002_2_clip_param-0.3000-entropy_coeff-0.0100-gamma-0.9500_2024-04-22_22-35-12.csv',
#  'test_2_PPO_Coup_8d620_00003_3_clip_param-0.1000-entropy_coeff-0.0010-gamma-0.9500_2024-04-22_23-24-59.csv',
#  'test_2_PPO_Coup_8d620_00004_4_clip_param-0.2000-entropy_coeff-0.0010-gamma-0.9500_2024-04-23_00-13-31.csv',
#  'test_2_PPO_Coup_8d620_00005_5_clip_param-0.3000-entropy_coeff-0.0010-gamma-0.9500_2024-04-23_01-01-54.csv',
#  'test_2_PPO_Coup_8d620_00006_6_clip_param-0.1000-entropy_coeff-0.0001-gamma-0.9500_2024-04-23_01-49-37.csv',
#  'test_2_PPO_Coup_8d620_00007_7_clip_param-0.2000-entropy_coeff-0.0001-gamma-0.9500_2024-04-23_02-37-05.csv',
#  'test_2_PPO_Coup_8d620_00008_8_clip_param-0.3000-entropy_coeff-0.0001-gamma-0.9500_2024-04-23_03-24-32.csv']

# %%
# help from https://stackoverflow.com/questions/9706845/increase-the-linewidth-of-the-legend-lines-in-matplotlib
# and https://stackoverflow.com/questions/15814635/prettier-default-plot-colors-in-matplotlib
import matplotlib.pyplot as plt
import seaborn as sns   



fig, ax = plt.subplots(figsize=(12, 10))

# colours = sns.color_palette("husl", 18)
# ax.set_prop_cycle('color', colours)
# set font size larger
plt.rcParams.update({'font.size': 18})


# set colour scheme to viridis


# y axis from 0 to 1
ax.set_ylim(0, 1)
ax.set_xlim(0,49)

ax.tick_params(axis='both', which='major', labelsize=24)

ax.set_xlabel("Training Iteration", fontsize=33)
ax.set_ylabel("Win Rate", fontsize=33)
# make lines plotted smaller

# plot each df
for df in dfs:
    ax.plot(df["Win Rate"])



plt.savefig('win_rate.pdf', format='pdf', bbox_inches='tight')
plt.savefig('win_rate.png', format='png', bbox_inches='tight')

# handles, labels = ax.get_legend_handles_labels()


# for handle in handles:
#     handle.set_linewidth(6)
# leg = plt.legend(hyperparams, loc="lower right",handlelength=3)

# for legobj in leg.legendHandles:
#     legobj.set_linewidth(10)

# ax.legend = leg
